# %% [markdown]
# ## Loading data into Pandas

# %%
# !wget https://github.com/KeithGalli/pandas/blob/d0025fc924d0eb00aa65a157e5086001fda0b780/pokemon_data.csv
# !wget https://github.com/KeithGalli/pandas/blob/d0025fc924d0eb00aa65a157e5086001fda0b780/pokemon_data.xlsx
# !wget https://github.com/KeithGalli/pandas/blob/d0025fc924d0eb00aa65a157e5086001fda0b780/pokemon_data.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("pokemon_data.csv")
# df = pd.read_csv("/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
print(df)
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
print(df.head(5))
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [3 rows x 12 columns]

# %%
df_xlsx = pd.read_excel('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.xlsx')
print(df_xlsx.head(3))
# Out:
#    #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2    Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3   Venusaur  Grass  Poison  ...      100     80           1      False
#
# [3 rows x 12 columns]

# %%
df_txt = pd.read_csv('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.txt')
print(df_txt.head(3))
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...

# %%
df_txt = pd.read_csv('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.txt', delimiter='\t')

print(df_txt.head(5))
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
df['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df[['Name']])
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
print(df.Name)
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Read each Column
print(df[['Name', 'Type 1', 'HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
print(df.iloc[1])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
print(df.iloc[2:5])
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [3 rows x 12 columns]

# %%
# Read Each Row
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [4 rows x 12 columns]

# %%
print(df.iloc[2,3])
# Out:
# Poison

# %%
# Read a specific location (R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
print(df.iloc[:,0:3])
# Out:
#        #                   Name   Type 1
# 0      1              Bulbasaur    Grass
# 1      2                Ivysaur    Grass
# 2      3               Venusaur    Grass
# 3      3  VenusaurMega Venusaur    Grass
# 4      4             Charmander     Fire
# ..   ...                    ...      ...
# 795  719                Diancie     Rock
# 796  719    DiancieMega Diancie     Rock
# 797  720    HoopaHoopa Confined  Psychic
# 798  720     HoopaHoopa Unbound  Psychic
# 799  721              Volcanion     Fire
#
# [800 rows x 3 columns]

# %%
# for index, row in df.iterrows():
#     print(index, row)

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
for index, row in df.iterrows():
    print(index, row['Name'],row['Speed'])
# Out:
# 0 Bulbasaur 45
# 1 Ivysaur 60
# 2 Venusaur 80
# 3 VenusaurMega Venusaur 80
# 4 Charmander 65
# 5 Charmeleon 80
# 6 Charizard 100
# 7 CharizardMega Charizard X 100
# 8 CharizardMega Charizard Y 100
# 9 Squirtle 43
# 10 Wartortle 58
# 11 Blastoise 78
# 12 BlastoiseMega Blastoise 78
# 13 Caterpie 45
# 14 Metapod 30
# 15 Butterfree 70
# 16 Weedle 50
# 17 Kakuna 35
# 18 Beedrill 75
# 19 BeedrillMega Beedrill 145
# 20 Pidgey 56
# 21 Pidgeotto 71
# 22 Pidgeot 101
# 23 PidgeotMega Pidgeot 121
# 24 Rattata 72
# 25 Raticate 97
# 26 Spearow 70
# 27 Fearow 100
# 28 Ekans 55
# 29 Arbok 80
# 30 Pikachu 90
# 31 Raichu 110
# 32 Sandshrew 40
# 33 Sandslash 65
# 34 Nidoran (Female) 41
# 35 Nidorina 56
# 36 Nidoqueen 76
# 37 Nidoran (Male) 50
# 38 Nidorino 65
# 39 Nidoking 85
# 40 Clefairy 35
# 41 Clefable 60
# 42 Vulpix 65
# 43 Ninetales 100
# 44 Jigglypuff 20
# 45 Wigglytuff 45
# 46 Zubat 55
# 47 Golbat 90
# 48 Oddish 30
# 49 Gloom 40
# 50 Vileplume 50
# 51 Paras 25
# 52 Parasect 30
# 53 Venonat 45
# ...

# %%
df.loc[df['Type 1'] == "Grass" ]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [70 rows x 12 columns]

# %%
df.describe()
# Out:
#                 #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.000000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    208.343798   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.000000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# ## Sorting/Describing Data

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 510  460                Abomasnow    Grass  ...    60           4      False
# 511  460  AbomasnowMega Abomasnow    Grass  ...    30           4      False
# 68    63                     Abra  Psychic  ...    90           1      False
# 392  359                    Absol     Dark  ...    75           3      False
# 393  359          AbsolMega Absol     Dark  ...   115           3      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 632  571                  Zoroark     Dark  ...   105           5      False
# 631  570                    Zorua     Dark  ...    65           5      False
# 46    41                    Zubat   Poison  ...    55           1      False
# 695  634                 Zweilous     Dark  ...    58           5      False
# 794  718         Zygarde50% Forme   Dragon  ...    95           6       True
#
# [800 rows x 12 columns]

# %%
df.sort_values('Name').head()
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 510  460                Abomasnow    Grass  ...    60           4      False
# 511  460  AbomasnowMega Abomasnow    Grass  ...    30           4      False
# 68    63                     Abra  Psychic  ...    90           1      False
# 392  359                    Absol     Dark  ...    75           3      False
# 393  359          AbsolMega Absol     Dark  ...   115           3      False
#
# [5 rows x 12 columns]

# %%
df.sort_values('Name' , ascending=False).head()
# Out:
#        #              Name  Type 1  ... Speed  Generation  Legendary
# 794  718  Zygarde50% Forme  Dragon  ...    95           6       True
# 695  634          Zweilous    Dark  ...    58           5      False
# 46    41             Zubat  Poison  ...    55           1      False
# 631  570             Zorua    Dark  ...    65           5      False
# 632  571           Zoroark    Dark  ...   105           5      False
#
# [5 rows x 12 columns]

# %%
df.sort_values(['Type 1','HP']).head()
# Out:
#        #      Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 316  292  Shedinja    Bug   Ghost  ...       30     40           3      False
# 230  213   Shuckle    Bug    Rock  ...      230      5           2      False
# 462  415    Combee    Bug  Flying  ...       42     70           4      False
# 603  543  Venipede    Bug  Poison  ...       39     57           5      False
# 314  290   Nincada    Bug  Ground  ...       30     40           3      False
#
# [5 rows x 12 columns]

# %%
df.sort_values(['Type 1','HP'],ascending=False).head()
# Out:
#        #       Name Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 351  321    Wailord  Water    NaN  ...       45     60           3      False
# 655  594  Alomomola  Water    NaN  ...       45     65           5      False
# 142  131     Lapras  Water    Ice  ...       95     60           1      False
# 145  134   Vaporeon  Water    NaN  ...       95     65           1      False
# 350  320    Wailmer  Water    NaN  ...       35     60           3      False
#
# [5 rows x 12 columns]

# %%
df.sort_values(['Type 1','HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1  ... Speed  Generation  Legendary
# 520  469                  Yanmega    Bug  ...    95           4      False
# 698  637                Volcarona    Bug  ...   100           5      False
# 231  214                Heracross    Bug  ...    85           2      False
# 232  214  HeracrossMega Heracross    Bug  ...    75           2      False
# 678  617                 Accelgor    Bug  ...   145           5      False
# ..   ...                      ...    ...  ...   ...         ...        ...
# 106   98                   Krabby  Water  ...    50           1      False
# 125  116                   Horsea  Water  ...    60           1      False
# 129  120                   Staryu  Water  ...    85           1      False
# 139  129                 Magikarp  Water  ...    80           1      False
# 381  349                   Feebas  Water  ...    80           3      False
#
# [800 rows x 12 columns]

# %%
df.sort_values(['Type 1','Defense','HP']).head()
# Out:
#        #      Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 16    13    Weedle    Bug  Poison  ...       20     50           1      False
# 179  165    Ledyba    Bug  Flying  ...       80     55           2      False
# 307  283   Surskit    Bug   Water  ...       52     65           3      False
# 13    10  Caterpie    Bug     NaN  ...       20     45           1      False
# 288  265   Wurmple    Bug     NaN  ...       30     20           3      False
#
# [5 rows x 12 columns]

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1,0])

df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Speed  Generation  Legendary  Total
# 0  1              Bulbasaur  Grass  Poison  ...     45           1      False    318
# 1  2                Ivysaur  Grass  Poison  ...     60           1      False    405
# 2  3               Venusaur  Grass  Poison  ...     80           1      False    525
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...     80           1      False    625
# 4  4             Charmander   Fire     NaN  ...     65           1      False    309
#
# [5 rows x 13 columns]

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
df = df.drop(columns=['Total'])
df.head(5)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
df.to_csv('modified.csv', index=False)

# %%
df.to_excel('modified.xlsx', index=False)

# %%
df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
new_df1 = df.loc[(df['Type 1'] == 'Grass')]
new_df1
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [70 rows x 13 columns]

# %%
new_df2 = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
new_df2
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# 49    44                  Gloom  Grass  ...    40           1      False
# 50    45              Vileplume  Grass  ...    50           1      False
# 75    69             Bellsprout  Grass  ...    40           1      False
# 76    70             Weepinbell  Grass  ...    55           1      False
# 77    71             Victreebel  Grass  ...    70           1      False
# 344  315                Roselia  Grass  ...    65           3      False
# 451  406                  Budew  Grass  ...    55           4      False
# ...

# %%
new_df3 = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
new_df3
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 16    13                 Weedle    Bug  ...    50           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [89 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.to_csv('filtered.csv')

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df  = new_df.reset_index()

new_df
# Out:
#    index    #                   Name  ... Speed Generation  Legendary
# 0      2    3               Venusaur  ...    80          1      False
# 1      3    3  VenusaurMega Venusaur  ...    80          1      False
# 2     50   45              Vileplume  ...    50          1      False
# 3     77   71             Victreebel  ...    70          1      False
# 4    652  591              Amoonguss  ...    30          5      False
#
# [5 rows x 14 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df  = new_df.reset_index(drop=True)

new_df
# Out:
#      #                   Name Type 1  ... Speed  Generation  Legendary
# 0    3               Venusaur  Grass  ...    80           1      False
# 1    3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 2   45              Vileplume  Grass  ...    50           1      False
# 3   71             Victreebel  Grass  ...    70           1      False
# 4  591              Amoonguss  Grass  ...    30           5      False
#
# [5 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#      #                   Name Type 1  ... Speed  Generation  Legendary
# 0    3               Venusaur  Grass  ...    80           1      False
# 1    3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 2   45              Vileplume  Grass  ...    50           1      False
# 3   71             Victreebel  Grass  ...    70           1      False
# 4  591              Amoonguss  Grass  ...    30           5      False
#
# [5 rows x 13 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.csv')
df.loc[df["Name"].str.contains('Mega')]
# Out:
#        #                       Name    Type 1  ... Speed  Generation  Legendary
# 3      3      VenusaurMega Venusaur     Grass  ...    80           1      False
# 7      6  CharizardMega Charizard X      Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y      Fire  ...   100           1      False
# 12     9    BlastoiseMega Blastoise     Water  ...    78           1      False
# 19    15      BeedrillMega Beedrill       Bug  ...   145           1      False
# 23    18        PidgeotMega Pidgeot    Normal  ...   121           1      False
# 71    65      AlakazamMega Alakazam   Psychic  ...   150           1      False
# 87    80        SlowbroMega Slowbro     Water  ...    30           1      False
# 102   94          GengarMega Gengar     Ghost  ...   130           1      False
# 124  115  KangaskhanMega Kangaskhan    Normal  ...   100           1      False
# 137  127          PinsirMega Pinsir       Bug  ...   105           1      False
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.csv')
df.loc[~df["Name"].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 0      1            Bulbasaur    Grass  ...    45           1      False
# 1      2              Ivysaur    Grass  ...    60           1      False
# 2      3             Venusaur    Grass  ...    80           1      False
# 4      4           Charmander     Fire  ...    65           1      False
# 5      5           Charmeleon     Fire  ...    80           1      False
# ..   ...                  ...      ...  ...   ...         ...        ...
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [751 rows x 12 columns]

# %%
import re

df.loc[df["Type 1"].str.contains('Fire|Rock', regex=True)]
# Out:
#        #                       Name Type 1  ... Speed  Generation  Legendary
# 4      4                 Charmander   Fire  ...    65           1      False
# 5      5                 Charmeleon   Fire  ...    80           1      False
# 6      6                  Charizard   Fire  ...   100           1      False
# 7      6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y   Fire  ...   100           1      False
# ..   ...                        ...    ...  ...   ...         ...        ...
# 769  699                    Aurorus   Rock  ...    58           6      False
# 773  703                    Carbink   Rock  ...    50           6      False
# 795  719                    Diancie   Rock  ...    50           6       True
# 796  719        DiancieMega Diancie   Rock  ...   110           6       True
# 799  721                  Volcanion   Fire  ...    70           6       True
#
# [96 rows x 12 columns]

# %%
import re

df.loc[df["Name"].str.contains('^pi[a-z]*', flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1  ... Speed  Generation  Legendary
# 20    16               Pidgey    Normal  ...    56           1      False
# 21    17            Pidgeotto    Normal  ...    71           1      False
# 22    18              Pidgeot    Normal  ...   101           1      False
# 23    18  PidgeotMega Pidgeot    Normal  ...   121           1      False
# 30    25              Pikachu  Electric  ...    90           1      False
# 136  127               Pinsir       Bug  ...    85           1      False
# 137  127    PinsirMega Pinsir       Bug  ...   105           1      False
# 186  172                Pichu  Electric  ...    60           2      False
# 219  204               Pineco       Bug  ...    15           2      False
# 239  221            Piloswine       Ice  ...    50           2      False
# 438  393               Piplup     Water  ...    40           4      False
# 558  499              Pignite      Fire  ...    55           5      False
# ...

# %% [markdown]
# ## Conditional Changes

# %%
df = pd.read_csv('/content/drive/MyDrive/Collage(GNU)/My_Work_Manan-sir/data/pandas/pokemon_data.csv')

# %%
df.loc[df['Type 1'] =='Fire','Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander   Flamer  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion   Flamer  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df.loc[df['Type 1'] =='Flamer','Legendary'] = True
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander   Flamer  ...    65           1       True
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion   Flamer  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df = pd.read_csv('modified.csv')

df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80      Test 1     Test 2
# 3      3  VenusaurMega Venusaur    Grass  ...    80      Test 1     Test 2
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50      Test 1     Test 2
# 796  719    DiancieMega Diancie     Rock  ...   110      Test 1     Test 2
# 797  720    HoopaHoopa Confined  Psychic  ...    70      Test 1     Test 2
# 798  720     HoopaHoopa Unbound  Psychic  ...    80      Test 1     Test 2
# 799  721              Volcanion     Fire  ...    70      Test 1     Test 2
#
# [800 rows x 13 columns]

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #  Total    HP  Attack  ...  Sp. Def  Speed  Generation  Legendary
# Type 1                                ...
# Bug       23080  26146  3925    4897  ...     4471   4256         222          0
# Dark      14302  13818  2071    2740  ...     2155   2361         125          2
# Dragon    15180  17617  2666    3588  ...     2843   2657         124         12
# Electric  15994  19510  2631    3040  ...     3243   3718         144          4
# Fairy      7642   7024  1260    1046  ...     1440    826          70          1
# Fighting   9824  11244  1886    2613  ...     1747   1784          91          0
# Fire      17025  23820  3635    4408  ...     3755   3871         167          5
# Flying     2711   1940   283     315  ...      290    410          22          2
# Ghost     15568  14066  2062    2361  ...     2447   2059         134          2
# Grass     24141  29480  4709    5125  ...     4930   4335         235          3
# ...

# %%
df['count'] = 1
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  count
# 0      1              Bulbasaur    Grass  ...          1      False      1
# 1      2                Ivysaur    Grass  ...          1      False      1
# 2      3               Venusaur    Grass  ...          1      False      1
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False      1
# 4      4             Charmander     Fire  ...          1      False      1
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True      1
# 796  719    DiancieMega Diancie     Rock  ...          6       True      1
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True      1
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True      1
# 799  721              Volcanion     Fire  ...          6       True      1
#
# [800 rows x 14 columns]

# %%
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total  ...  Speed  Generation  Legendary  count
# Type 1                              ...
# Bug        69    69      52     69  ...     69          69         69     69
# Dark       31    31      21     31  ...     31          31         31     31
# Dragon     32    32      21     32  ...     32          32         32     32
# Electric   44    44      17     44  ...     44          44         44     44
# Fairy      17    17       2     17  ...     17          17         17     17
# Fighting   27    27       7     27  ...     27          27         27     27
# Fire       52    52      24     52  ...     52          52         52     52
# Flying      4     4       2      4  ...      4           4          4      4
# Ghost      32    32      22     32  ...     32          32         32     32
# Grass      70    70      37     70  ...     70          70         70     70
# Ground     32    32      19     32  ...     32          32         32     32
# ...

# %%
df.groupby(['Type 1']).mean()
# Out:
#                    #       Total         HP  ...  Generation  Legendary  count
# Type 1                                       ...
# Bug       334.492754  378.927536  56.884058  ...    3.217391   0.000000    1.0
# Dark      461.354839  445.741935  66.806452  ...    4.032258   0.064516    1.0
# Dragon    474.375000  550.531250  83.312500  ...    3.875000   0.375000    1.0
# Electric  363.500000  443.409091  59.795455  ...    3.272727   0.090909    1.0
# Fairy     449.529412  413.176471  74.117647  ...    4.117647   0.058824    1.0
# Fighting  363.851852  416.444444  69.851852  ...    3.370370   0.000000    1.0
# Fire      327.403846  458.076923  69.903846  ...    3.211538   0.096154    1.0
# Flying    677.750000  485.000000  70.750000  ...    5.500000   0.500000    1.0
# Ghost     486.500000  439.562500  64.437500  ...    4.187500   0.062500    1.0
# Grass     344.871429  421.142857  67.271429  ...    3.357143   0.042857    1.0
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)
# Out:
#                    #       Total         HP  ...  Generation  Legendary  count
# Type 1                                       ...
# Steel     442.851852  487.703704  65.222222  ...    3.851852   0.148148    1.0
# Rock      392.727273  453.750000  65.363636  ...    3.454545   0.090909    1.0
# Dragon    474.375000  550.531250  83.312500  ...    3.875000   0.375000    1.0
# Ground    356.281250  437.500000  73.781250  ...    3.156250   0.125000    1.0
# Ghost     486.500000  439.562500  64.437500  ...    4.187500   0.062500    1.0
# Water     303.089286  430.455357  72.062500  ...    2.857143   0.035714    1.0
# Ice       423.541667  433.458333  72.000000  ...    3.541667   0.083333    1.0
# Grass     344.871429  421.142857  67.271429  ...    3.357143   0.042857    1.0
# Bug       334.492754  378.927536  56.884058  ...    3.217391   0.000000    1.0
# Dark      461.354839  445.741935  66.806452  ...    4.032258   0.064516    1.0
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Attack',ascending=False)
# Out:
#                    #       Total         HP  ...  Generation  Legendary  count
# Type 1                                       ...
# Dragon    474.375000  550.531250  83.312500  ...    3.875000   0.375000    1.0
# Fighting  363.851852  416.444444  69.851852  ...    3.370370   0.000000    1.0
# Ground    356.281250  437.500000  73.781250  ...    3.156250   0.125000    1.0
# Rock      392.727273  453.750000  65.363636  ...    3.454545   0.090909    1.0
# Steel     442.851852  487.703704  65.222222  ...    3.851852   0.148148    1.0
# Dark      461.354839  445.741935  66.806452  ...    4.032258   0.064516    1.0
# Fire      327.403846  458.076923  69.903846  ...    3.211538   0.096154    1.0
# Flying    677.750000  485.000000  70.750000  ...    5.500000   0.500000    1.0
# Poison    251.785714  399.142857  67.250000  ...    2.535714   0.000000    1.0
# Water     303.089286  430.455357  72.062500  ...    2.857143   0.035714    1.0
# ...

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
for df in pd.read_csv('modified.csv', chunksize=5):
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]
# CHUNK DF
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [5 rows x 13 columns]
# CHUNK DF
# ...

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
